# %%
import os
import cv2
import numpy as np
import json
from pathlib import Path
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
# Configuration
VIDEO_DIR = "fortnite_videos"  # Directory containing the downloaded videos
FRAMES_DIR = "character_frames"  # Directory to save extracted frames
FRAMES_PER_ROTATION = 8  # Number of frames to extract per video (360 for full rotation)

# Create output directory
os.makedirs(FRAMES_DIR, exist_ok=True)

# %%
def extract_frames_from_video(video_path, num_frames=360):
    """
    Extract evenly spaced frames from a video
    
    Args:
        video_path: Path to the video file
        num_frames: Number of frames to extract (default 360 for full rotation)
    
    Returns:
        List of frames (numpy arrays)
    """
    cap = cv2.VideoCapture(str(video_path))
    
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return []
    
    # Get video properties
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    duration = total_frames / fps
    
    print(f"Video: {video_path.name}")
    print(f"  Total frames: {total_frames}, FPS: {fps:.2f}, Duration: {duration:.2f}s")
    
    # Calculate frame indices to extract
    if total_frames < num_frames:
        # If video has fewer frames than requested, take all frames
        frame_indices = list(range(total_frames))
        print(f"  Warning: Video has only {total_frames} frames, extracting all")
    else:
        # Extract evenly spaced frames
        frame_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    
    frames = []
    for frame_idx in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
        ret, frame = cap.read()
        if ret:
            frames.append(frame)
        else:
            print(f"  Warning: Could not read frame {frame_idx}")
    
    cap.release()
    print(f"  Extracted {len(frames)} frames")
    return frames

# %%
def save_frames_to_disk(frames, character_id, output_dir):
    """
    Save extracted frames to disk
    
    Args:
        frames: List of frames (numpy arrays)
        character_id: ID of the character
        output_dir: Directory to save frames
    
    Returns:
        List of saved file paths
    """
    character_dir = Path(output_dir) / character_id
    character_dir.mkdir(exist_ok=True)
    
    saved_files = []
    
    for i, frame in enumerate(frames):
        # Create filename with format: id_num (num starts from 1)
        frame_num = i + 1  # Start numbering from 1
        filename = f"{character_id}_{frame_num}.jpg"
        filepath = character_dir / filename
        
        # Save frame as JPEG
        cv2.imwrite(str(filepath), frame)
        saved_files.append(str(filepath))
    
    return saved_files

# %%
def process_video_for_frames(video_path, character_id, num_frames=360):
    """
    Process a single video to extract and save frames
    
    Args:
        video_path: Path to the video file
        character_id: ID of the character (from filename)
        num_frames: Number of frames to extract
    
    Returns:
        Dictionary containing processing results
    """
    print(f"\nProcessing {character_id}...")
    
    # Extract frames
    frames = extract_frames_from_video(video_path, num_frames)
    
    if not frames:
        print(f"  No frames extracted from {video_path}")
        return None
    
    # Save frames to disk
    print(f"  Saving {len(frames)} frames...")
    saved_files = save_frames_to_disk(frames, character_id, FRAMES_DIR)
    
    result = {
        'character_id': character_id,
        'total_frames': len(frames),
        'saved_files': saved_files,
        'output_directory': str(Path(FRAMES_DIR) / character_id)
    }
    
    print(f"  Successfully saved {len(saved_files)} frames to {result['output_directory']}")
    
    return result

# %%
def process_all_videos():
    """
    Process all videos in the VIDEO_DIR to extract frames
    """
    video_dir = Path(VIDEO_DIR)
    
    if not video_dir.exists():
        print(f"Error: Video directory {VIDEO_DIR} does not exist!")
        return
    
    # Find all video files
    video_files = list(video_dir.glob("*.mp4"))
    
    if not video_files:
        print(f"No .mp4 files found in {VIDEO_DIR}")
        return
    
    print(f"Found {len(video_files)} video files to process")
    
    all_results = {}
    failed_videos = []
    skipped_videos = []
    total_frames_saved = 0
    
    for video_file in video_files:
        # Extract character ID from filename (assuming format: ID.mp4)
        character_id = video_file.stem
        
        # Check if frames already exist for this character
        character_dir = Path(FRAMES_DIR) / character_id
        existing_frames = list(character_dir.glob(f"{character_id}_*.jpg")) if character_dir.exists() else []
        
        if existing_frames:
            print(f"\nSkipping {character_id} - {len(existing_frames)} frames already exist")
            skipped_videos.append(character_id)
            
            # Load existing metadata if available
            metadata_file = character_dir / "metadata.json"
            if metadata_file.exists():
                with open(metadata_file, 'r') as f:
                    result = json.load(f)
                    all_results[character_id] = result
            continue
        
        try:
            result = process_video_for_frames(video_file, character_id, FRAMES_PER_ROTATION)
            
            if result:
                all_results[character_id] = result
                total_frames_saved += result['total_frames']
                
                # Save individual character metadata
                metadata_file = Path(FRAMES_DIR) / character_id / "metadata.json"
                with open(metadata_file, 'w') as f:
                    json.dump(result, f, indent=2)
                
            else:
                failed_videos.append(character_id)
                
        except Exception as e:
            print(f"  Error processing {character_id}: {e}")
            failed_videos.append(character_id)
    
    # Save combined metadata
    combined_file = Path(FRAMES_DIR) / "all_characters_metadata.json"
    with open(combined_file, 'w') as f:
        json.dump(all_results, f, indent=2)
    
    # Print summary
    print(f"\n=== PROCESSING COMPLETE ===")
    print(f"Successfully processed: {len(all_results) - len(skipped_videos)} characters")
    print(f"Skipped (already exist): {len(skipped_videos)} characters")
    print(f"Failed: {len(failed_videos)} characters")
    print(f"Total frames saved: {total_frames_saved}")
    if skipped_videos:
        print(f"Skipped characters: {skipped_videos}")
    if failed_videos:
        print(f"Failed videos: {failed_videos}")
    print(f"Frames saved to: {FRAMES_DIR}")
    
    return all_results

# %%
def visualize_character_frames(character_id, max_frames_to_show=8):
    """
    Visualize saved frames for a character
    
    Args:
        character_id: ID of the character to visualize
        max_frames_to_show: Maximum number of frames to display
    """
    character_dir = Path(FRAMES_DIR) / character_id
    
    if not character_dir.exists():
        print(f"Frame directory not found for character {character_id}")
        return
    
    # Find all saved frames with new naming format
    frame_files = sorted(list(character_dir.glob(f"{character_id}_*.jpg")))
    
    if not frame_files:
        print(f"No frames found for character {character_id}")
        return
    
    # Select frames to display (up to max_frames_to_show)
    frames_to_show = frame_files[:max_frames_to_show]
    
    # Create subplots
    fig, axes = plt.subplots(2, 4, figsize=(16, 8))
    axes = axes.flatten()
    
    for i, frame_file in enumerate(frames_to_show):
        if i >= len(axes):
            break
            
        ax = axes[i]
        
        # Read and display frame
        frame = cv2.imread(str(frame_file))
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        ax.imshow(frame_rgb)
        
        # Extract frame number from filename (format: id_num.jpg)
        filename = frame_file.name
        frame_num = filename.split('_')[1].replace('.jpg', '')
        
        ax.set_title(f"Frame {frame_num}")
        ax.axis('off')
    
    # Hide unused subplots
    for i in range(len(frames_to_show), len(axes)):
        axes[i].axis('off')
    
    plt.suptitle(f"Character {character_id} - Frame Sequence", fontsize=16)
    plt.tight_layout()
    plt.show()
    
    print(f"Showing {len(frames_to_show)} frames out of {len(frame_files)} total frames")

# %%
# Execute the frame extraction
print("Starting frame extraction from all videos...")
all_results = process_all_videos()
# Out:
# Starting frame extraction from all videos...
# Found 2338 video files to process
#
# Skipping 8097 - 8 frames already exist
#
# Skipping 9549 - 8 frames already exist
#
# Skipping 18605 - 8 frames already exist
#
# Skipping 730 - 8 frames already exist
#
# Skipping 4307 - 8 frames already exist
#
# Skipping 6245 - 8 frames already exist
#
# Skipping 432 - 8 frames already exist
#
# Skipping 905 - 8 frames already exist
#
# Skipping 16696 - 8 frames already exist
#
# Skipping 11447 - 8 frames already exist
#
# Skipping 76 - 8 frames already exist
#
# Skipping 10094 - 8 frames already exist
#
# Skipping 201 - 8 frames already exist
#
# Skipping 16189 - 8 frames already exist
#
# Skipping 4616 - 8 frames already exist
#
# Skipping 743 - 8 frames already exist
#
# Skipping 11326 - 8 frames already exist
#
# Skipping 10645 - 8 frames already exist
#
# Skipping 8024 - 8 frames already exist
#
# Skipping 3269 - 8 frames already exist
#
# Skipping 19172 - 8 frames already exist
#
# Skipping 9556 - 8 frames already exist
#
# Skipping 8098 - 8 frames already exist
#
# Skipping 5312 - 8 frames already exist
#
# Skipping 6156 - 8 frames already exist
#
# Skipping 10643 - 8 frames already exist
#
# Skipping 5245 - 8 frames already exist
#
# Skipping 469 - 8 frames already exist
#
# Skipping 6700 - 8 frames already exist
#
# Skipping 686 - 8 frames already exist
#
# Skipping 9664 - 8 frames already exist
#
# Skipping 674 - 8 frames already exist
#
# Skipping 10552 - 8 frames already exist
#
# Skipping 391 - 8 frames already exist
#
# Skipping 9710 - 8 frames already exist
#
# Skipping 5883 - 8 frames already exist
#
# Skipping 17789 - 8 frames already exist
#
# Skipping 809 - 8 frames already exist
#
# Skipping 595 - 8 frames already exist
#
# Skipping 9662 - 8 frames already exist
#
# Skipping 539 - 8 frames already exist
#
# Skipping 18939 - 8 frames already exist
#
# Skipping 4293 - 8 frames already exist
#
# Skipping 218 - 8 frames already exist
#
# Skipping 17408 - 8 frames already exist
#
# Skipping 442 - 8 frames already exist
#
# Skipping 4378 - 8 frames already exist
#
# Skipping 4488 - 8 frames already exist
#
# Skipping 652 - 8 frames already exist
#
# Skipping 245 - 8 frames already exist
#
# Skipping 11565 - 8 frames already exist
#
# Skipping 17792 - 8 frames already exist
#
# Skipping 677 - 8 frames already exist
#
# Skipping 348 - 8 frames already exist
#
# Skipping 478 - 8 frames already exist
#
# Skipping 518 - 8 frames already exist
#
# Skipping 12411 - 8 frames already exist
#
# Skipping 188 - 8 frames already exist
#
# Skipping 568 - 8 frames already exist
#
# Skipping 15083 - 8 frames already exist
#
# Skipping 408 - 8 frames already exist
#
# Skipping 18863 - 8 frames already exist
#
# Skipping 32 - 8 frames already exist
#
# Skipping 5451 - 8 frames already exist
#
# Skipping 149 - 8 frames already exist
#
# Skipping 4399 - 8 frames already exist
#
# Skipping 78 - 8 frames already exist
#
# Skipping 9949 - 8 frames already exist
#
# Skipping 8960 - 8 frames already exist
#
# Skipping 306 - 8 frames already exist
#
# Skipping 380 - 8 frames already exist
#
# Skipping 6159 - 8 frames already exist
#
# Processing 128...
# Video: 128.mp4
#   Total frames: 268, FPS: 60.00, Duration: 4.47s
#   Extracted 8 frames
#   Saving 8 frames...
#   Successfully saved 8 frames to character_frames/128
#
# Skipping 11446 - 8 frames already exist
#
# Skipping 12162 - 8 frames already exist
#
# Skipping 11318 - 8 frames already exist
#
# Skipping 8878 - 8 frames already exist
#
# Skipping 10092 - 8 frames already exist
#
# Skipping 14451 - 8 frames already exist
#
# Skipping 12040 - 8 frames already exist
#
# Skipping 266 - 8 frames already exist
#
# Skipping 8705 - 8 frames already exist
#
# Skipping 465 - 8 frames already exist
#
# Skipping 628 - 8 frames already exist
#
# Skipping 17848 - 8 frames already exist
#
# Skipping 268 - 8 frames already exist
#
# Skipping 16193 - 8 frames already exist
#
# Skipping 11564 - 8 frames already exist
#
# Skipping 220 - 8 frames already exist
#
# Skipping 398 - 8 frames already exist
#
# Skipping 6761 - 8 frames already exist
#
# Skipping 803 - 8 frames already exist
#
# Skipping 4938 - 8 frames already exist
#
# Processing 19...
# Video: 19.mp4
#   Total frames: 268, FPS: 60.00, Duration: 4.47s
#   Extracted 8 frames
#   Saving 8 frames...
#   Successfully saved 8 frames to character_frames/128
#
# Skipping 11446 - 8 frames already exist
#
# Skipping 12162 - 8 frames already exist
#
# Skipping 11318 - 8 frames already exist
#
# Skipping 8878 - 8 frames already exist
#
# Skipping 10092 - 8 frames already exist
#
# Skipping 14451 - 8 frames already exist
#
# Skipping 12040 - 8 frames already exist
#
# Skipping 266 - 8 frames already exist
#
# Skipping 8705 - 8 frames already exist
#
# Skipping 465 - 8 frames already exist
#
# Skipping 628 - 8 frames already exist
#
# Skipping 17848 - 8 frames already exist
#
# Skipping 268 - 8 frames already exist
#
# Skipping 16193 - 8 frames already exist
#
# Skipping 11564 - 8 frames already exist
#
# Skipping 220 - 8 frames already exist
#
# Skipping 398 - 8 frames already exist
#
# Skipping 6761 - 8 frames already exist
#
# Skipping 803 - 8 frames already exist
#
# Skipping 4938 - 8 frames already exist
#
# Processing 19...
# Video: 19.mp4
#   Total frames: 268, FPS: 60.00, Duration: 4.47s
#   Extracted 8 frames
#   Saving 8 frames...
#   Successfully saved 8 frames to character_frames/19
#
# Skipping 6615 - 8 frames already exist
#
# Skipping 836 - 8 frames already exist
#
# Skipping 193 - 8 frames already exist
#
# Skipping 369 - 8 frames already exist
#
# Skipping 12749 - 8 frames already exist
#
# Skipping 9071 - 8 frames already exist
#
# Skipping 34 - 8 frames already exist
#
# Skipping 9560 - 8 frames already exist
#
# Skipping 10008 - 8 frames already exist
#
# Skipping 574 - 8 frames already exist
#
# Skipping 740 - 8 frames already exist
#
# Skipping 6764 - 8 frames already exist
#
# Skipping 17143 - 8 frames already exist
#
# Skipping 14512 - 8 frames already exist
#
# Skipping 399 - 8 frames already exist
#
# Skipping 641 - 8 frames already exist
#
# Skipping 11013 - 8 frames already exist
#
# Skipping 467 - 8 frames already exist
#
# Skipping 17149 - 8 frames already exist
#
# Skipping 5175 - 8 frames already exist
#
# Skipping 3292 - 8 frames already exist
#
# Skipping 5774 - 8 frames already exist
#
# Skipping 675 - 8 frames already exist
#
# Skipping 124 - 8 frames already exist
#
# Skipping 5928 - 8 frames already exist
#
# Skipping 4303 - 8 frames already exist
#
# Skipping 10454 - 8 frames already exist
#
# Skipping 8021 - 8 frames already exist
#
# Skipping 139 - 8 frames already exist
#
# Skipping 5081 - 8 frames already exist
#
# Skipping 16912 - 8 frames already exist
#
# Skipping 427 - 8 frames already exist
#
# Skipping 8780 - 8 frames already exist
#
# Skipping 5169 - 8 frames already exist
#
# Skipping 9832 - 8 frames already exist
#
# Skipping 7781 - 8 frames already exist
#
# Skipping 11223 - 8 frames already exist
#
# Skipping 7785 - 8 frames already exist
#
# Skipping 104 - 8 frames already exist
#
# Skipping 15565 - 8 frames already exist
#
# Skipping 12141 - 8 frames already exist
#
# Skipping 9711 - 8 frames already exist
#
# Skipping 15983 - 8 frames already exist
#
# Skipping 12750 - 8 frames already exist
#
# Skipping 643 - 8 frames already exist
#
# Skipping 5528 - 8 frames already exist
#
# Skipping 9552 - 8 frames already exist
#
# Skipping 414 - 8 frames already exist
#
# Skipping 10491 - 8 frames already exist
#
# Skipping 11320 - 8 frames already exist
#
# Skipping 11 - 8 frames already exist
#
# Skipping 15086 - 8 frames already exist
#
# Skipping 822 - 8 frames already exist
#
# Skipping 17150 - 8 frames already exist
#
# Skipping 487 - 8 frames already exist
#
# Skipping 11915 - 8 frames already exist
#
# Skipping 17567 - 8 frames already exist
#
# Skipping 17582 - 8 frames already exist
#
# Skipping 4897 - 8 frames already exist
#
# Skipping 11569 - 8 frames already exist
#
# Skipping 8339 - 8 frames already exist
#
# Skipping 10534 - 8 frames already exist
#
# Skipping 18073 - 8 frames already exist
#
# Skipping 15088 - 8 frames already exist
#
# Skipping 173 - 8 frames already exist
#
# Skipping 7777 - 8 frames already exist
#
# Skipping 780 - 8 frames already exist
#
# Skipping 14702 - 8 frames already exist
#
# Skipping 365 - 8 frames already exist
#
# Skipping 488 - 8 frames already exist
#
# Skipping 17132 - 8 frames already exist
#
# Skipping 2 - 8 frames already exist
#
# Skipping 460 - 8 frames already exist
#
# Skipping 540 - 8 frames already exist
#
# Skipping 4389 - 8 frames already exist
#
# Skipping 9708 - 8 frames already exist
#
# Skipping 15571 - 8 frames already exist
#
# Skipping 17944 - 8 frames already exist
#
# Skipping 308 - 8 frames already exist
#
# Skipping 4729 - 8 frames already exist
#
# Skipping 704 - 8 frames already exist
#
# Skipping 16679 - 8 frames already exist
#
# Skipping 16686 - 8 frames already exist
#
# Skipping 745 - 8 frames already exist
#
# Skipping 5244 - 8 frames already exist
#
# Skipping 17083 - 8 frames already exist
#
# Skipping 762 - 8 frames already exist
#
# Skipping 17571 - 8 frames already exist
#
# Skipping 10521 - 8 frames already exist
#
# Skipping 5442 - 8 frames already exist
#
# Skipping 546 - 8 frames already exist
#
# Skipping 6291 - 8 frames already exist
#
# Skipping 11443 - 8 frames already exist
#
# Skipping 495 - 8 frames already exist
#
# Skipping 19101 - 8 frames already exist
#
# Skipping 176 - 8 frames already exist
#
# Skipping 17787 - 8 frames already exist
#
# Skipping 234 - 8 frames already exist
#
# Skipping 16198 - 8 frames already exist
#
# Skipping 9448 - 8 frames already exist
#
# Skipping 334 - 8 frames already exist
#
# Skipping 6516 - 8 frames already exist
#
# Skipping 3319 - 8 frames already exist
#
# Skipping 248 - 8 frames already exist
#
# Skipping 214 - 8 frames already exist
#
# Skipping 5726 - 8 frames already exist
#
# Skipping 166 - 8 frames already exist
#
# Skipping 8235 - 8 frames already exist
#
# Skipping 722 - 8 frames already exist
#
# Skipping 5247 - 8 frames already exist
#
# Skipping 14447 - 8 frames already exist
#
# Skipping 6026 - 8 frames already exist
#
# Skipping 739 - 8 frames already exist
#
# Skipping 6009 - 8 frames already exist
#
# Skipping 19109 - 8 frames already exist
#
# Skipping 5858 - 8 frames already exist
#
# Skipping 15982 - 8 frames already exist
#
# Skipping 216 - 8 frames already exist
#
# Skipping 898 - 8 frames already exist
#
# Skipping 14154 - 8 frames already exist
#
# Skipping 8337 - 8 frames already exist
#
# Skipping 558 - 8 frames already exist
#
# Skipping 18340 - 8 frames already exist
#
# Skipping 195 - 8 frames already exist
#
# Skipping 508 - 8 frames already exist
#
# Skipping 11322 - 8 frames already exist
#
# Skipping 11222 - 8 frames already exist
#
# Skipping 459 - 8 frames already exist
#
# Skipping 12835 - 8 frames already exist
#
# Skipping 8668 - 8 frames already exist
#
# Skipping 41 - 8 frames already exist
#
# Skipping 15794 - 8 frames already exist
#
# Skipping 14152 - 8 frames already exist
#
# Skipping 11217 - 8 frames already exist
#
# Skipping 871 - 8 frames already exist
#
# Skipping 6131 - 8 frames already exist
#
# Skipping 19246 - 8 frames already exist
#
# Skipping 8191 - 8 frames already exist
#
# Skipping 17701 - 8 frames already exist
#
# Skipping 879 - 8 frames already exist
#
# Skipping 45 - 8 frames already exist
#
# Skipping 361 - 8 frames already exist
#
# Skipping 336 - 8 frames already exist
#
# Skipping 4606 - 8 frames already exist
#
# Skipping 6587 - 8 frames already exist
#
# Skipping 18343 - 8 frames already exist
#
# Skipping 4494 - 8 frames already exist
#
# Skipping 553 - 8 frames already exist
#
# Skipping 519 - 8 frames already exist
#
# Skipping 282 - 8 frames already exist
#
# Skipping 17137 - 8 frames already exist
#
# Skipping 603 - 8 frames already exist
#
# Skipping 240 - 8 frames already exist
#
# Skipping 19243 - 8 frames already exist
#
# Skipping 798 - 8 frames already exist
#
# Skipping 11024 - 8 frames already exist
#
# Skipping 9716 - 8 frames already exist
#
# Skipping 12138 - 8 frames already exist
#
# Skipping 8959 - 8 frames already exist
#
# Skipping 280 - 8 frames already exist
#
# Skipping 669 - 8 frames already exist
#
# Skipping 11014 - 8 frames already exist
#
# Skipping 8331 - 8 frames already exist
#
# Skipping 5153 - 8 frames already exist
#
# Skipping 5064 - 8 frames already exist
#
# Skipping 14511 - 8 frames already exist
#
# Skipping 106 - 8 frames already exist
#
# Skipping 35 - 8 frames already exist
#
# Skipping 6465 - 8 frames already exist
#
# Skipping 523 - 8 frames already exist
#
# Skipping 4301 - 8 frames already exist
#
# Skipping 9449 - 8 frames already exist
#
# Skipping 8341 - 8 frames already exist
#
# Skipping 659 - 8 frames already exist
#
# Skipping 393 - 8 frames already exist
#
# Skipping 10486 - 8 frames already exist
#
# Skipping 573 - 8 frames already exist
#
# Skipping 869 - 8 frames already exist
#
# Skipping 291 - 8 frames already exist
#
# Skipping 10821 - 8 frames already exist
#
# Skipping 17134 - 8 frames already exist
#
# Skipping 6521 - 8 frames already exist
#
# Skipping 15034 - 8 frames already exist
#
# Skipping 229 - 8 frames already exist
#
# Skipping 876 - 8 frames already exist
#
# Skipping 12019 - 8 frames already exist
#
# Skipping 4462 - 8 frames already exist
#
# Skipping 125 - 8 frames already exist
#
# Skipping 9669 - 8 frames already exist
#
# Skipping 6244 - 8 frames already exist
#
# Skipping 16899 - 8 frames already exist
#
# Skipping 5080 - 8 frames already exist
#
# Skipping 815 - 8 frames already exist
#
# Skipping 5659 - 8 frames already exist
#
# Skipping 107 - 8 frames already exist
#
# Skipping 12219 - 8 frames already exist
#
# Skipping 9614 - 8 frames already exist
#
# Skipping 19098 - 8 frames already exist
#
# Skipping 11449 - 8 frames already exist
#
# Skipping 294 - 8 frames already exist
#
# Skipping 17491 - 8 frames already exist
#
# Skipping 645 - 8 frames already exist
#
# Skipping 728 - 8 frames already exist
#
# Skipping 531 - 8 frames already exist
#
# Skipping 333 - 8 frames already exist
#
# Skipping 213 - 8 frames already exist
#
# Skipping 153 - 8 frames already exist
#
# Skipping 845 - 8 frames already exist
#
# Skipping 5525 - 8 frames already exist
#
# Skipping 6215 - 8 frames already exist
#
# Skipping 18074 - 8 frames already exist
#
# Skipping 812 - 8 frames already exist
#
# Skipping 11819 - 8 frames already exist
#
# Skipping 14510 - 8 frames already exist
#
# Skipping 196 - 8 frames already exist
#
# Skipping 15578 - 8 frames already exist
#
# Skipping 437 - 8 frames already exist
#
# Skipping 8515 - 8 frames already exist
#
# Skipping 5251 - 8 frames already exist
#
# Skipping 6720 - 8 frames already exist
#
# Processing 71...
# Video: 71.mp4
#   Total frames: 269, FPS: 60.00, Duration: 4.48s
#   Extracted 8 frames
#   Saving 8 frames...
#   Successfully saved 8 frames to character_frames/19
#
# Skipping 6615 - 8 frames already exist
#
# Skipping 836 - 8 frames already exist
#
# Skipping 193 - 8 frames already exist
#
# Skipping 369 - 8 frames already exist
#
# Skipping 12749 - 8 frames already exist
#
# Skipping 9071 - 8 frames already exist
#
# Skipping 34 - 8 frames already exist
#
# Skipping 9560 - 8 frames already exist
#
# Skipping 10008 - 8 frames already exist
#
# Skipping 574 - 8 frames already exist
#
# Skipping 740 - 8 frames already exist
#
# Skipping 6764 - 8 frames already exist
#
# Skipping 17143 - 8 frames already exist
#
# Skipping 14512 - 8 frames already exist
#
# Skipping 399 - 8 frames already exist
#
# Skipping 641 - 8 frames already exist
#
# Skipping 11013 - 8 frames already exist
#
# Skipping 467 - 8 frames already exist
#
# Skipping 17149 - 8 frames already exist
#
# Skipping 5175 - 8 frames already exist
#
# Skipping 3292 - 8 frames already exist
#
# Skipping 5774 - 8 frames already exist
#
# Skipping 675 - 8 frames already exist
#
# Skipping 124 - 8 frames already exist
#
# Skipping 5928 - 8 frames already exist
#
# Skipping 4303 - 8 frames already exist
#
# Skipping 10454 - 8 frames already exist
#
# Skipping 8021 - 8 frames already exist
#
# Skipping 139 - 8 frames already exist
#
# Skipping 5081 - 8 frames already exist
#
# Skipping 16912 - 8 frames already exist
#
# Skipping 427 - 8 frames already exist
#
# Skipping 8780 - 8 frames already exist
#
# Skipping 5169 - 8 frames already exist
#
# Skipping 9832 - 8 frames already exist
#
# Skipping 7781 - 8 frames already exist
#
# Skipping 11223 - 8 frames already exist
#
# Skipping 7785 - 8 frames already exist
#
# Skipping 104 - 8 frames already exist
#
# Skipping 15565 - 8 frames already exist
#
# Skipping 12141 - 8 frames already exist
#
# Skipping 9711 - 8 frames already exist
#
# Skipping 15983 - 8 frames already exist
#
# Skipping 12750 - 8 frames already exist
#
# Skipping 643 - 8 frames already exist
#
# Skipping 5528 - 8 frames already exist
#
# Skipping 9552 - 8 frames already exist
#
# Skipping 414 - 8 frames already exist
#
# Skipping 10491 - 8 frames already exist
#
# Skipping 11320 - 8 frames already exist
#
# Skipping 11 - 8 frames already exist
#
# Skipping 15086 - 8 frames already exist
#
# Skipping 822 - 8 frames already exist
#
# Skipping 17150 - 8 frames already exist
#
# Skipping 487 - 8 frames already exist
#
# Skipping 11915 - 8 frames already exist
#
# Skipping 17567 - 8 frames already exist
#
# Skipping 17582 - 8 frames already exist
#
# Skipping 4897 - 8 frames already exist
#
# Skipping 11569 - 8 frames already exist
#
# Skipping 8339 - 8 frames already exist
#
# Skipping 10534 - 8 frames already exist
#
# Skipping 18073 - 8 frames already exist
#
# Skipping 15088 - 8 frames already exist
#
# Skipping 173 - 8 frames already exist
#
# Skipping 7777 - 8 frames already exist
#
# Skipping 780 - 8 frames already exist
#
# Skipping 14702 - 8 frames already exist
#
# Skipping 365 - 8 frames already exist
#
# Skipping 488 - 8 frames already exist
#
# Skipping 17132 - 8 frames already exist
#
# Skipping 2 - 8 frames already exist
#
# Skipping 460 - 8 frames already exist
#
# Skipping 540 - 8 frames already exist
#
# Skipping 4389 - 8 frames already exist
#
# Skipping 9708 - 8 frames already exist
#
# Skipping 15571 - 8 frames already exist
#
# Skipping 17944 - 8 frames already exist
#
# Skipping 308 - 8 frames already exist
#
# Skipping 4729 - 8 frames already exist
#
# Skipping 704 - 8 frames already exist
#
# Skipping 16679 - 8 frames already exist
#
# Skipping 16686 - 8 frames already exist
#
# Skipping 745 - 8 frames already exist
#
# Skipping 5244 - 8 frames already exist
#
# Skipping 17083 - 8 frames already exist
#
# Skipping 762 - 8 frames already exist
#
# Skipping 17571 - 8 frames already exist
#
# Skipping 10521 - 8 frames already exist
#
# Skipping 5442 - 8 frames already exist
#
# Skipping 546 - 8 frames already exist
#
# Skipping 6291 - 8 frames already exist
#
# Skipping 11443 - 8 frames already exist
#
# Skipping 495 - 8 frames already exist
#
# Skipping 19101 - 8 frames already exist
#
# Skipping 176 - 8 frames already exist
#
# Skipping 17787 - 8 frames already exist
#
# Skipping 234 - 8 frames already exist
#
# Skipping 16198 - 8 frames already exist
#
# Skipping 9448 - 8 frames already exist
#
# Skipping 334 - 8 frames already exist
#
# Skipping 6516 - 8 frames already exist
#
# Skipping 3319 - 8 frames already exist
#
# Skipping 248 - 8 frames already exist
#
# Skipping 214 - 8 frames already exist
#
# Skipping 5726 - 8 frames already exist
#
# Skipping 166 - 8 frames already exist
#
# Skipping 8235 - 8 frames already exist
#
# Skipping 722 - 8 frames already exist
#
# Skipping 5247 - 8 frames already exist
#
# Skipping 14447 - 8 frames already exist
#
# Skipping 6026 - 8 frames already exist
#
# Skipping 739 - 8 frames already exist
#
# Skipping 6009 - 8 frames already exist
#
# Skipping 19109 - 8 frames already exist
#
# Skipping 5858 - 8 frames already exist
#
# Skipping 15982 - 8 frames already exist
#
# Skipping 216 - 8 frames already exist
#
# Skipping 898 - 8 frames already exist
#
# Skipping 14154 - 8 frames already exist
#
# Skipping 8337 - 8 frames already exist
#
# Skipping 558 - 8 frames already exist
#
# Skipping 18340 - 8 frames already exist
#
# Skipping 195 - 8 frames already exist
#
# Skipping 508 - 8 frames already exist
#
# Skipping 11322 - 8 frames already exist
#
# Skipping 11222 - 8 frames already exist
#
# Skipping 459 - 8 frames already exist
#
# Skipping 12835 - 8 frames already exist
#
# Skipping 8668 - 8 frames already exist
#
# Skipping 41 - 8 frames already exist
#
# Skipping 15794 - 8 frames already exist
#
# Skipping 14152 - 8 frames already exist
#
# Skipping 11217 - 8 frames already exist
#
# Skipping 871 - 8 frames already exist
#
# Skipping 6131 - 8 frames already exist
#
# Skipping 19246 - 8 frames already exist
#
# Skipping 8191 - 8 frames already exist
#
# Skipping 17701 - 8 frames already exist
#
# Skipping 879 - 8 frames already exist
#
# Skipping 45 - 8 frames already exist
#
# Skipping 361 - 8 frames already exist
#
# Skipping 336 - 8 frames already exist
#
# Skipping 4606 - 8 frames already exist
#
# Skipping 6587 - 8 frames already exist
#
# Skipping 18343 - 8 frames already exist
#
# Skipping 4494 - 8 frames already exist
#
# Skipping 553 - 8 frames already exist
#
# Skipping 519 - 8 frames already exist
#
# Skipping 282 - 8 frames already exist
#
# Skipping 17137 - 8 frames already exist
#
# Skipping 603 - 8 frames already exist
#
# Skipping 240 - 8 frames already exist
#
# Skipping 19243 - 8 frames already exist
#
# Skipping 798 - 8 frames already exist
#
# Skipping 11024 - 8 frames already exist
#
# Skipping 9716 - 8 frames already exist
#
# Skipping 12138 - 8 frames already exist
#
# Skipping 8959 - 8 frames already exist
#
# Skipping 280 - 8 frames already exist
#
# Skipping 669 - 8 frames already exist
#
# Skipping 11014 - 8 frames already exist
#
# Skipping 8331 - 8 frames already exist
#
# Skipping 5153 - 8 frames already exist
#
# Skipping 5064 - 8 frames already exist
#
# Skipping 14511 - 8 frames already exist
#
# Skipping 106 - 8 frames already exist
#
# Skipping 35 - 8 frames already exist
#
# Skipping 6465 - 8 frames already exist
#
# Skipping 523 - 8 frames already exist
#
# Skipping 4301 - 8 frames already exist
#
# Skipping 9449 - 8 frames already exist
#
# Skipping 8341 - 8 frames already exist
#
# Skipping 659 - 8 frames already exist
#
# Skipping 393 - 8 frames already exist
#
# Skipping 10486 - 8 frames already exist
#
# Skipping 573 - 8 frames already exist
#
# Skipping 869 - 8 frames already exist
#
# Skipping 291 - 8 frames already exist
#
# Skipping 10821 - 8 frames already exist
#
# Skipping 17134 - 8 frames already exist
#
# Skipping 6521 - 8 frames already exist
#
# Skipping 15034 - 8 frames already exist
#
# Skipping 229 - 8 frames already exist
#
# Skipping 876 - 8 frames already exist
#
# Skipping 12019 - 8 frames already exist
#
# Skipping 4462 - 8 frames already exist
#
# Skipping 125 - 8 frames already exist
#
# Skipping 9669 - 8 frames already exist
#
# Skipping 6244 - 8 frames already exist
#
# Skipping 16899 - 8 frames already exist
#
# Skipping 5080 - 8 frames already exist
#
# Skipping 815 - 8 frames already exist
#
# Skipping 5659 - 8 frames already exist
#
# Skipping 107 - 8 frames already exist
#
# Skipping 12219 - 8 frames already exist
#
# Skipping 9614 - 8 frames already exist
#
# Skipping 19098 - 8 frames already exist
#
# Skipping 11449 - 8 frames already exist
#
# Skipping 294 - 8 frames already exist
#
# Skipping 17491 - 8 frames already exist
#
# Skipping 645 - 8 frames already exist
#
# Skipping 728 - 8 frames already exist
#
# Skipping 531 - 8 frames already exist
#
# Skipping 333 - 8 frames already exist
#
# Skipping 213 - 8 frames already exist
#
# Skipping 153 - 8 frames already exist
#
# Skipping 845 - 8 frames already exist
#
# Skipping 5525 - 8 frames already exist
#
# Skipping 6215 - 8 frames already exist
#
# Skipping 18074 - 8 frames already exist
#
# Skipping 812 - 8 frames already exist
#
# Skipping 11819 - 8 frames already exist
#
# Skipping 14510 - 8 frames already exist
#
# Skipping 196 - 8 frames already exist
#
# Skipping 15578 - 8 frames already exist
#
# Skipping 437 - 8 frames already exist
#
# Skipping 8515 - 8 frames already exist
#
# Skipping 5251 - 8 frames already exist
#
# Skipping 6720 - 8 frames already exist
#
# Processing 71...
# Video: 71.mp4
#   Total frames: 269, FPS: 60.00, Duration: 4.48s
#   Extracted 8 frames
#   Saving 8 frames...
#   Successfully saved 8 frames to character_frames/71
#
# Skipping 18352 - 8 frames already exist
#
# Skipping 17122 - 8 frames already exist
#
# Skipping 167 - 8 frames already exist
#
# Skipping 647 - 8 frames already exist
#
# Skipping 12755 - 8 frames already exist
#
# Skipping 4490 - 8 frames already exist
#
# Skipping 575 - 8 frames already exist
#
# Skipping 821 - 8 frames already exist
#
# Skipping 494 - 8 frames already exist
#
# Skipping 18179 - 8 frames already exist
#
# Skipping 16029 - 8 frames already exist
#
# Skipping 199 - 8 frames already exist
#
# Skipping 18938 - 8 frames already exist
#
# Skipping 8125 - 8 frames already exist
#
# Skipping 254 - 8 frames already exist
#
# Skipping 18604 - 8 frames already exist
#
# Skipping 208 - 8 frames already exist
#
# Skipping 567 - 8 frames already exist
#
# Skipping 9545 - 8 frames already exist
#
# Skipping 515 - 8 frames already exist
#
# Skipping 18858 - 8 frames already exist
#
# Skipping 5330 - 8 frames already exist
#
# Skipping 9291 - 8 frames already exist
#
# Skipping 4640 - 8 frames already exist
#
# Skipping 5859 - 8 frames already exist
#
# Skipping 19108 - 8 frames already exist
#
# Skipping 8632 - 8 frames already exist
#
# Skipping 372 - 8 frames already exist
#
# Skipping 11319 - 8 frames already exist
#
# Skipping 353 - 8 frames already exist
#
# Skipping 707 - 8 frames already exist
#
# Skipping 148 - 8 frames already exist
#
# Skipping 5180 - 8 frames already exist
#
# Skipping 19255 - 8 frames already exist
#
# Skipping 9667 - 8 frames already exist
#
# Skipping 755 - 8 frames already exist
#
# Skipping 17148 - 8 frames already exist
#
# Skipping 894 - 8 frames already exist
#
# Skipping 695 - 8 frames already exist
#
# Skipping 648 - 8 frames already exist
#
# Skipping 5444 - 8 frames already exist
#
# Skipping 48 - 8 frames already exist
#
# Skipping 15977 - 8 frames already exist
#
# Skipping 14504 - 8 frames already exist
#
# Skipping 8744 - 8 frames already exist
#
# Skipping 4486 - 8 frames already exist
#
# Skipping 5927 - 8 frames already exist
#
# Skipping 5243 - 8 frames already exist
#
# Skipping 524 - 8 frames already exist
#
# Skipping 260 - 8 frames already exist
#
# Skipping 6241 - 8 frames already exist
#
# Skipping 9198 - 8 frames already exist
#
# Skipping 11567 - 8 frames already exist
#
# Skipping 12405 - 8 frames already exist
#
# Skipping 6706 - 8 frames already exist
#
# Skipping 18855 - 8 frames already exist
#
# Skipping 856 - 8 frames already exist
#
# Skipping 17152 - 8 frames already exist
#
# Skipping 17126 - 8 frames already exist
#
# Skipping 883 - 8 frames already exist
#
# Skipping 18945 - 8 frames already exist
#
# Skipping 9455 - 8 frames already exist
#
# Skipping 16186 - 8 frames already exist
#
# Skipping 10429 - 8 frames already exist
#
# Skipping 17145 - 8 frames already exist
#
# Skipping 10826 - 8 frames already exist
#
# Skipping 9070 - 8 frames already exist
#
# Skipping 4602 - 8 frames already exist
#
# Skipping 367 - 8 frames already exist
#
# Skipping 285 - 8 frames already exist
#
# Skipping 272 - 8 frames already exist
#
# Skipping 12218 - 8 frames already exist
#
# Skipping 11910 - 8 frames already exist
#
# Skipping 5443 - 8 frames already exist
#
# Skipping 10009 - 8 frames already exist
#
# Skipping 746 - 8 frames already exist
#
# Skipping 11916 - 8 frames already exist
#
# Skipping 790 - 8 frames already exist
#
# Skipping 16621 - 8 frames already exist
#
# Skipping 18075 - 8 frames already exist
#
# Skipping 16816 - 8 frames already exist
#
# Skipping 605 - 8 frames already exist
#
# Skipping 5526 - 8 frames already exist
#
# Skipping 9068 - 8 frames already exist
#
# Skipping 10085 - 8 frames already exist
#
# Skipping 551 - 8 frames already exist
#
# Skipping 59 - 8 frames already exist
#
# Skipping 10089 - 8 frames already exist
#
# Skipping 7606 - 8 frames already exist
#
# Skipping 779 - 8 frames already exist
#
# Skipping 43 - 8 frames already exist
#
# Skipping 6401 - 8 frames already exist
#
# Skipping 9630 - 8 frames already exist
#
# Skipping 12401 - 8 frames already exist
#
# Skipping 350 - 8 frames already exist
#
# Skipping 4768 - 8 frames already exist
#
# Skipping 11909 - 8 frames already exist
#
# Skipping 525 - 8 frames already exist
#
# Skipping 5297 - 8 frames already exist
#
# Skipping 19068 - 8 frames already exist
#
# Skipping 4283 - 8 frames already exist
#
# Skipping 5366 - 8 frames already exist
#
# Skipping 4683 - 8 frames already exist
#
# Skipping 4369 - 8 frames already exist
#
# Skipping 526 - 8 frames already exist
#
# Skipping 112 - 8 frames already exist
#
# Skipping 517 - 8 frames already exist
#
# Skipping 263 - 8 frames already exist
#
# Skipping 8023 - 8 frames already exist
#
# Skipping 9406 - 8 frames already exist
#
# Skipping 10819 - 8 frames already exist
#
# Skipping 17780 - 8 frames already exist
#
# Skipping 621 - 8 frames already exist
#
# Skipping 19046 - 8 frames already exist
#
# Skipping 439 - 8 frames already exist
#
# Skipping 912 - 8 frames already exist
#
# Skipping 8765 - 8 frames already exist
#
# Skipping 163 - 8 frames already exist
#
# Skipping 355 - 8 frames already exist
#
# Skipping 119 - 8 frames already exist
#
# Skipping 18334 - 8 frames already exist
#
# Skipping 499 - 8 frames already exist
#
# Skipping 5769 - 8 frames already exist
#
# Skipping 777 - 8 frames already exist
#
# Skipping 720 - 8 frames already exist
#
# Skipping 11815 - 8 frames already exist
#
# Skipping 10062 - 8 frames already exist
#
# Skipping 9497 - 8 frames already exist
#
# Skipping 15445 - 8 frames already exist
#
# Skipping 9040 - 8 frames already exist
#
# Skipping 751 - 8 frames already exist
#
# Skipping 4391 - 8 frames already exist
#
# Skipping 23 - 8 frames already exist
#
# Skipping 6236 - 8 frames already exist
#
# Skipping 6338 - 8 frames already exist
#
# Skipping 11818 - 8 frames already exist
#
# Skipping 9958 - 8 frames already exist
#
# Skipping 346 - 8 frames already exist
#
# Skipping 17579 - 8 frames already exist
#
# Skipping 692 - 8 frames already exist
#
# Skipping 5085 - 8 frames already exist
#
# Skipping 15569 - 8 frames already exist
#
# Skipping 17783 - 8 frames already exist
#
# Skipping 12577 - 8 frames already exist
#
# Skipping 9035 - 8 frames already exist
#
# Skipping 8192 - 8 frames already exist
#
# Skipping 8554 - 8 frames already exist
#
# Skipping 4753 - 8 frames already exist
#
# Skipping 9267 - 8 frames already exist
#
# Skipping 412 - 8 frames already exist
#
# Skipping 62 - 8 frames already exist
#
# Skipping 283 - 8 frames already exist
#
# Skipping 347 - 8 frames already exist
#
# Skipping 12402 - 8 frames already exist
#
# Skipping 9550 - 8 frames already exist
#
# Skipping 4903 - 8 frames already exist
#
# Skipping 15579 - 8 frames already exist
#
# Skipping 200 - 8 frames already exist
#
# Skipping 17575 - 8 frames already exist
#
# Skipping 7784 - 8 frames already exist
#
# Skipping 8900 - 8 frames already exist
#
# Skipping 15000 - 8 frames already exist
#
# Skipping 9657 - 8 frames already exist
#
# Skipping 785 - 8 frames already exist
#
# Skipping 15577 - 8 frames already exist
#
# Skipping 9069 - 8 frames already exist
#
# Skipping 4607 - 8 frames already exist
#
# Skipping 17493 - 8 frames already exist
#
# Skipping 4651 - 8 frames already exist
#
# Skipping 6403 - 8 frames already exist
#
# Skipping 9498 - 8 frames already exist
#
# Skipping 666 - 8 frames already exist
#
# Skipping 16090 - 8 frames already exist
#
# Skipping 16690 - 8 frames already exist
#
# Skipping 9132 - 8 frames already exist
#
# Skipping 492 - 8 frames already exist
#
# Skipping 4926 - 8 frames already exist
#
# Skipping 17130 - 8 frames already exist
#
# Skipping 4491 - 8 frames already exist
#
# Skipping 462 - 8 frames already exist
#
# Skipping 12165 - 8 frames already exist
#
# Skipping 631 - 8 frames already exist
#
# Skipping 572 - 8 frames already exist
#
# Skipping 737 - 8 frames already exist
#
# Skipping 17492 - 8 frames already exist
#
# Skipping 506 - 8 frames already exist
#
# Skipping 19020 - 8 frames already exist
#
# Skipping 696 - 8 frames already exist
#
# Skipping 799 - 8 frames already exist
#
# Skipping 324 - 8 frames already exist
#
# Skipping 204 - 8 frames already exist
#
# Skipping 10637 - 8 frames already exist
#
# Skipping 4600 - 8 frames already exist
#
# Skipping 620 - 8 frames already exist
#
# Skipping 3282 - 8 frames already exist
#
# Skipping 17399 - 8 frames already exist
#
# Skipping 24 - 8 frames already exist
#
# Skipping 6426 - 8 frames already exist
#
# Skipping 151 - 8 frames already exist
#
# Skipping 57 - 8 frames already exist
#
# Skipping 11816 - 8 frames already exist
#
# Skipping 11716 - 8 frames already exist
#
# Skipping 264 - 8 frames already exist
#
# Skipping 562 - 8 frames already exist
#
# Skipping 5587 - 8 frames already exist
#
# Skipping 288 - 8 frames already exist
#
# Skipping 19049 - 8 frames already exist
#
# Skipping 16693 - 8 frames already exist
#
# Skipping 5563 - 8 frames already exist
#
# Skipping 8 - 8 frames already exist
#
# Skipping 17397 - 8 frames already exist
#
# Skipping 4447 - 8 frames already exist
#
# Skipping 16050 - 8 frames already exist
#
# Skipping 5368 - 8 frames already exist
#
# Skipping 9953 - 8 frames already exist
#
# Skipping 4902 - 8 frames already exist
#
# Skipping 11445 - 8 frames already exist
#
# Skipping 8442 - 8 frames already exist
#
# Skipping 11271 - 8 frames already exist
#
# Skipping 5672 - 8 frames already exist
#
# Skipping 6728 - 8 frames already exist
#
# Skipping 11332 - 8 frames already exist
#
# Skipping 782 - 8 frames already exist
#
# Skipping 12400 - 8 frames already exist
#
# Skipping 15572 - 8 frames already exist
#
# Skipping 8085 - 8 frames already exist
#
# Skipping 9 - 8 frames already exist
#
# Skipping 325 - 8 frames already exist
#
# Skipping 725 - 8 frames already exist
#
# Skipping 274 - 8 frames already exist
#
# Skipping 8472 - 8 frames already exist
#
# Skipping 435 - 8 frames already exist
#
# Skipping 877 - 8 frames already exist
#
# Skipping 9289 - 8 frames already exist
#
# Skipping 18653 - 8 frames already exist
#
# Skipping 423 - 8 frames already exist
#
# Skipping 143 - 8 frames already exist
#
# Skipping 490 - 8 frames already exist
#
# Skipping 4308 - 8 frames already exist
#
# Skipping 668 - 8 frames already exist
#
# Skipping 14802 - 8 frames already exist
#
# Skipping 18234 - 8 frames already exist
#
# Skipping 6240 - 8 frames already exist
#
# Skipping 19461 - 8 frames already exist
#
# Skipping 5250 - 8 frames already exist
#
# Skipping 15449 - 8 frames already exist
#
# Skipping 512 - 8 frames already exist
#
# Skipping 8332 - 8 frames already exist
#
# Skipping 510 - 8 frames already exist
#
# Skipping 157 - 8 frames already exist
#
# Skipping 11996 - 8 frames already exist
#
# Skipping 637 - 8 frames already exist
#
# Skipping 6385 - 8 frames already exist
#
# Skipping 597 - 8 frames already exist
#
# Skipping 258 - 8 frames already exist
#
# Skipping 19069 - 8 frames already exist
#
# Skipping 10091 - 8 frames already exist
#
# Skipping 19254 - 8 frames already exist
#
# Skipping 3293 - 8 frames already exist
#
# Skipping 16900 - 8 frames already exist
#
# Skipping 18661 - 8 frames already exist
#
# Skipping 39 - 8 frames already exist
#
# Skipping 11224 - 8 frames already exist
#
# Skipping 5445 - 8 frames already exist
#
# Skipping 10733 - 8 frames already exist
#
# Skipping 115 - 8 frames already exist
#
# Skipping 606 - 8 frames already exist
#
# Skipping 6151 - 8 frames already exist
#
# Skipping 337 - 8 frames already exist
#
# Skipping 5608 - 8 frames already exist
#
# Skipping 5645 - 8 frames already exist
#
# Skipping 178 - 8 frames already exist
#
# Skipping 543 - 8 frames already exist
#
# Skipping 326 - 8 frames already exist
#
# Skipping 235 - 8 frames already exist
#
# Skipping 320 - 8 frames already exist
#
# Skipping 17151 - 8 frames already exist
#
# Skipping 11441 - 8 frames already exist
#
# Skipping 300 - 8 frames already exist
#
# Skipping 5246 - 8 frames already exist
#
# Skipping 5673 - 8 frames already exist
#
# Skipping 9661 - 8 frames already exist
#
# Skipping 11912 - 8 frames already exist
#
# Skipping 4371 - 8 frames already exist
#
# Skipping 4487 - 8 frames already exist
#
# Skipping 18655 - 8 frames already exist
#
# Skipping 5166 - 8 frames already exist
#
# Skipping 97 - 8 frames already exist
#
# Skipping 8696 - 8 frames already exist
#
# Skipping 16910 - 8 frames already exist
#
# Skipping 16688 - 8 frames already exist
#
# Skipping 18606 - 8 frames already exist
#
# Skipping 434 - 8 frames already exist
#
# Processing 191...
# Video: 191.mp4
#   Total frames: 269, FPS: 60.00, Duration: 4.48s
#   Extracted 8 frames
#   Saving 8 frames...
#   Successfully saved 8 frames to character_frames/71
#
# Skipping 18352 - 8 frames already exist
#
# Skipping 17122 - 8 frames already exist
#
# Skipping 167 - 8 frames already exist
#
# Skipping 647 - 8 frames already exist
#
# Skipping 12755 - 8 frames already exist
#
# Skipping 4490 - 8 frames already exist
#
# Skipping 575 - 8 frames already exist
#
# Skipping 821 - 8 frames already exist
#
# Skipping 494 - 8 frames already exist
#
# Skipping 18179 - 8 frames already exist
#
# Skipping 16029 - 8 frames already exist
#
# Skipping 199 - 8 frames already exist
#
# Skipping 18938 - 8 frames already exist
#
# Skipping 8125 - 8 frames already exist
#
# Skipping 254 - 8 frames already exist
#
# Skipping 18604 - 8 frames already exist
#
# Skipping 208 - 8 frames already exist
#
# Skipping 567 - 8 frames already exist
#
# Skipping 9545 - 8 frames already exist
#
# Skipping 515 - 8 frames already exist
#
# Skipping 18858 - 8 frames already exist
#
# Skipping 5330 - 8 frames already exist
#
# Skipping 9291 - 8 frames already exist
#
# Skipping 4640 - 8 frames already exist
#
# Skipping 5859 - 8 frames already exist
#
# Skipping 19108 - 8 frames already exist
#
# Skipping 8632 - 8 frames already exist
#
# Skipping 372 - 8 frames already exist
#
# Skipping 11319 - 8 frames already exist
#
# Skipping 353 - 8 frames already exist
#
# Skipping 707 - 8 frames already exist
#
# Skipping 148 - 8 frames already exist
#
# Skipping 5180 - 8 frames already exist
#
# Skipping 19255 - 8 frames already exist
#
# Skipping 9667 - 8 frames already exist
#
# Skipping 755 - 8 frames already exist
#
# Skipping 17148 - 8 frames already exist
#
# Skipping 894 - 8 frames already exist
#
# Skipping 695 - 8 frames already exist
#
# Skipping 648 - 8 frames already exist
#
# Skipping 5444 - 8 frames already exist
#
# Skipping 48 - 8 frames already exist
#
# Skipping 15977 - 8 frames already exist
#
# Skipping 14504 - 8 frames already exist
#
# Skipping 8744 - 8 frames already exist
#
# Skipping 4486 - 8 frames already exist
#
# Skipping 5927 - 8 frames already exist
#
# Skipping 5243 - 8 frames already exist
#
# Skipping 524 - 8 frames already exist
#
# Skipping 260 - 8 frames already exist
#
# Skipping 6241 - 8 frames already exist
#
# Skipping 9198 - 8 frames already exist
#
# Skipping 11567 - 8 frames already exist
#
# Skipping 12405 - 8 frames already exist
#
# Skipping 6706 - 8 frames already exist
#
# Skipping 18855 - 8 frames already exist
#
# Skipping 856 - 8 frames already exist
#
# Skipping 17152 - 8 frames already exist
#
# Skipping 17126 - 8 frames already exist
#
# Skipping 883 - 8 frames already exist
#
# Skipping 18945 - 8 frames already exist
#
# Skipping 9455 - 8 frames already exist
#
# Skipping 16186 - 8 frames already exist
#
# Skipping 10429 - 8 frames already exist
#
# Skipping 17145 - 8 frames already exist
#
# Skipping 10826 - 8 frames already exist
#
# Skipping 9070 - 8 frames already exist
#
# Skipping 4602 - 8 frames already exist
#
# Skipping 367 - 8 frames already exist
#
# Skipping 285 - 8 frames already exist
#
# Skipping 272 - 8 frames already exist
#
# Skipping 12218 - 8 frames already exist
#
# Skipping 11910 - 8 frames already exist
#
# Skipping 5443 - 8 frames already exist
#
# Skipping 10009 - 8 frames already exist
#
# Skipping 746 - 8 frames already exist
#
# Skipping 11916 - 8 frames already exist
#
# Skipping 790 - 8 frames already exist
#
# Skipping 16621 - 8 frames already exist
#
# Skipping 18075 - 8 frames already exist
#
# Skipping 16816 - 8 frames already exist
#
# Skipping 605 - 8 frames already exist
#
# Skipping 5526 - 8 frames already exist
#
# Skipping 9068 - 8 frames already exist
#
# Skipping 10085 - 8 frames already exist
#
# Skipping 551 - 8 frames already exist
#
# Skipping 59 - 8 frames already exist
#
# Skipping 10089 - 8 frames already exist
#
# Skipping 7606 - 8 frames already exist
#
# Skipping 779 - 8 frames already exist
#
# Skipping 43 - 8 frames already exist
#
# Skipping 6401 - 8 frames already exist
#
# Skipping 9630 - 8 frames already exist
#
# Skipping 12401 - 8 frames already exist
#
# Skipping 350 - 8 frames already exist
#
# Skipping 4768 - 8 frames already exist
#
# Skipping 11909 - 8 frames already exist
#
# Skipping 525 - 8 frames already exist
#
# Skipping 5297 - 8 frames already exist
#
# Skipping 19068 - 8 frames already exist
#
# Skipping 4283 - 8 frames already exist
#
# Skipping 5366 - 8 frames already exist
#
# Skipping 4683 - 8 frames already exist
#
# Skipping 4369 - 8 frames already exist
#
# Skipping 526 - 8 frames already exist
#
# Skipping 112 - 8 frames already exist
#
# Skipping 517 - 8 frames already exist
#
# Skipping 263 - 8 frames already exist
#
# Skipping 8023 - 8 frames already exist
#
# Skipping 9406 - 8 frames already exist
#
# Skipping 10819 - 8 frames already exist
#
# Skipping 17780 - 8 frames already exist
#
# Skipping 621 - 8 frames already exist
#
# Skipping 19046 - 8 frames already exist
#
# Skipping 439 - 8 frames already exist
#
# Skipping 912 - 8 frames already exist
#
# Skipping 8765 - 8 frames already exist
#
# Skipping 163 - 8 frames already exist
#
# Skipping 355 - 8 frames already exist
#
# Skipping 119 - 8 frames already exist
#
# Skipping 18334 - 8 frames already exist
#
# Skipping 499 - 8 frames already exist
#
# Skipping 5769 - 8 frames already exist
#
# Skipping 777 - 8 frames already exist
#
# Skipping 720 - 8 frames already exist
#
# Skipping 11815 - 8 frames already exist
#
# Skipping 10062 - 8 frames already exist
#
# Skipping 9497 - 8 frames already exist
#
# Skipping 15445 - 8 frames already exist
#
# Skipping 9040 - 8 frames already exist
#
# Skipping 751 - 8 frames already exist
#
# Skipping 4391 - 8 frames already exist
#
# Skipping 23 - 8 frames already exist
#
# Skipping 6236 - 8 frames already exist
#
# Skipping 6338 - 8 frames already exist
#
# Skipping 11818 - 8 frames already exist
#
# Skipping 9958 - 8 frames already exist
#
# Skipping 346 - 8 frames already exist
#
# Skipping 17579 - 8 frames already exist
#
# Skipping 692 - 8 frames already exist
#
# Skipping 5085 - 8 frames already exist
#
# Skipping 15569 - 8 frames already exist
#
# Skipping 17783 - 8 frames already exist
#
# Skipping 12577 - 8 frames already exist
#
# Skipping 9035 - 8 frames already exist
#
# Skipping 8192 - 8 frames already exist
#
# Skipping 8554 - 8 frames already exist
#
# Skipping 4753 - 8 frames already exist
#
# Skipping 9267 - 8 frames already exist
#
# Skipping 412 - 8 frames already exist
#
# Skipping 62 - 8 frames already exist
#
# Skipping 283 - 8 frames already exist
#
# Skipping 347 - 8 frames already exist
#
# Skipping 12402 - 8 frames already exist
#
# Skipping 9550 - 8 frames already exist
#
# Skipping 4903 - 8 frames already exist
#
# Skipping 15579 - 8 frames already exist
#
# Skipping 200 - 8 frames already exist
#
# Skipping 17575 - 8 frames already exist
#
# Skipping 7784 - 8 frames already exist
#
# Skipping 8900 - 8 frames already exist
#
# Skipping 15000 - 8 frames already exist
#
# Skipping 9657 - 8 frames already exist
#
# Skipping 785 - 8 frames already exist
#
# Skipping 15577 - 8 frames already exist
#
# Skipping 9069 - 8 frames already exist
#
# Skipping 4607 - 8 frames already exist
#
# Skipping 17493 - 8 frames already exist
#
# Skipping 4651 - 8 frames already exist
#
# Skipping 6403 - 8 frames already exist
#
# Skipping 9498 - 8 frames already exist
#
# Skipping 666 - 8 frames already exist
#
# Skipping 16090 - 8 frames already exist
#
# Skipping 16690 - 8 frames already exist
#
# Skipping 9132 - 8 frames already exist
#
# Skipping 492 - 8 frames already exist
#
# Skipping 4926 - 8 frames already exist
#
# Skipping 17130 - 8 frames already exist
#
# Skipping 4491 - 8 frames already exist
#
# Skipping 462 - 8 frames already exist
#
# Skipping 12165 - 8 frames already exist
#
# Skipping 631 - 8 frames already exist
#
# Skipping 572 - 8 frames already exist
#
# Skipping 737 - 8 frames already exist
#
# Skipping 17492 - 8 frames already exist
#
# Skipping 506 - 8 frames already exist
#
# Skipping 19020 - 8 frames already exist
#
# Skipping 696 - 8 frames already exist
#
# Skipping 799 - 8 frames already exist
#
# Skipping 324 - 8 frames already exist
#
# Skipping 204 - 8 frames already exist
#
# Skipping 10637 - 8 frames already exist
#
# Skipping 4600 - 8 frames already exist
#
# Skipping 620 - 8 frames already exist
#
# Skipping 3282 - 8 frames already exist
#
# Skipping 17399 - 8 frames already exist
#
# Skipping 24 - 8 frames already exist
#
# Skipping 6426 - 8 frames already exist
#
# Skipping 151 - 8 frames already exist
#
# Skipping 57 - 8 frames already exist
#
# Skipping 11816 - 8 frames already exist
#
# Skipping 11716 - 8 frames already exist
#
# Skipping 264 - 8 frames already exist
#
# Skipping 562 - 8 frames already exist
#
# Skipping 5587 - 8 frames already exist
#
# Skipping 288 - 8 frames already exist
#
# Skipping 19049 - 8 frames already exist
#
# Skipping 16693 - 8 frames already exist
#
# Skipping 5563 - 8 frames already exist
#
# Skipping 8 - 8 frames already exist
#
# Skipping 17397 - 8 frames already exist
#
# Skipping 4447 - 8 frames already exist
#
# Skipping 16050 - 8 frames already exist
#
# Skipping 5368 - 8 frames already exist
#
# Skipping 9953 - 8 frames already exist
#
# Skipping 4902 - 8 frames already exist
#
# Skipping 11445 - 8 frames already exist
#
# Skipping 8442 - 8 frames already exist
#
# Skipping 11271 - 8 frames already exist
#
# Skipping 5672 - 8 frames already exist
#
# Skipping 6728 - 8 frames already exist
#
# Skipping 11332 - 8 frames already exist
#
# Skipping 782 - 8 frames already exist
#
# Skipping 12400 - 8 frames already exist
#
# Skipping 15572 - 8 frames already exist
#
# Skipping 8085 - 8 frames already exist
#
# Skipping 9 - 8 frames already exist
#
# Skipping 325 - 8 frames already exist
#
# Skipping 725 - 8 frames already exist
#
# Skipping 274 - 8 frames already exist
#
# Skipping 8472 - 8 frames already exist
#
# Skipping 435 - 8 frames already exist
#
# Skipping 877 - 8 frames already exist
#
# Skipping 9289 - 8 frames already exist
#
# Skipping 18653 - 8 frames already exist
#
# Skipping 423 - 8 frames already exist
#
# Skipping 143 - 8 frames already exist
#
# Skipping 490 - 8 frames already exist
#
# Skipping 4308 - 8 frames already exist
#
# Skipping 668 - 8 frames already exist
#
# Skipping 14802 - 8 frames already exist
#
# Skipping 18234 - 8 frames already exist
#
# Skipping 6240 - 8 frames already exist
#
# Skipping 19461 - 8 frames already exist
#
# Skipping 5250 - 8 frames already exist
#
# Skipping 15449 - 8 frames already exist
#
# Skipping 512 - 8 frames already exist
#
# Skipping 8332 - 8 frames already exist
#
# Skipping 510 - 8 frames already exist
#
# Skipping 157 - 8 frames already exist
#
# Skipping 11996 - 8 frames already exist
#
# Skipping 637 - 8 frames already exist
#
# Skipping 6385 - 8 frames already exist
#
# Skipping 597 - 8 frames already exist
#
# Skipping 258 - 8 frames already exist
#
# Skipping 19069 - 8 frames already exist
#
# Skipping 10091 - 8 frames already exist
#
# Skipping 19254 - 8 frames already exist
#
# Skipping 3293 - 8 frames already exist
#
# Skipping 16900 - 8 frames already exist
#
# Skipping 18661 - 8 frames already exist
#
# Skipping 39 - 8 frames already exist
#
# Skipping 11224 - 8 frames already exist
#
# Skipping 5445 - 8 frames already exist
#
# Skipping 10733 - 8 frames already exist
#
# Skipping 115 - 8 frames already exist
#
# Skipping 606 - 8 frames already exist
#
# Skipping 6151 - 8 frames already exist
#
# Skipping 337 - 8 frames already exist
#
# Skipping 5608 - 8 frames already exist
#
# Skipping 5645 - 8 frames already exist
#
# Skipping 178 - 8 frames already exist
#
# Skipping 543 - 8 frames already exist
#
# Skipping 326 - 8 frames already exist
#
# Skipping 235 - 8 frames already exist
#
# Skipping 320 - 8 frames already exist
#
# Skipping 17151 - 8 frames already exist
#
# Skipping 11441 - 8 frames already exist
#
# Skipping 300 - 8 frames already exist
#
# Skipping 5246 - 8 frames already exist
#
# Skipping 5673 - 8 frames already exist
#
# Skipping 9661 - 8 frames already exist
#
# Skipping 11912 - 8 frames already exist
#
# Skipping 4371 - 8 frames already exist
#
# Skipping 4487 - 8 frames already exist
#
# Skipping 18655 - 8 frames already exist
#
# Skipping 5166 - 8 frames already exist
#
# Skipping 97 - 8 frames already exist
#
# Skipping 8696 - 8 frames already exist
#
# Skipping 16910 - 8 frames already exist
#
# Skipping 16688 - 8 frames already exist
#
# Skipping 18606 - 8 frames already exist
#
# Skipping 434 - 8 frames already exist
#
# Processing 191...
# Video: 191.mp4
#   Total frames: 269, FPS: 60.00, Duration: 4.48s
#   Extracted 8 frames
#   Saving 8 frames...
#   Successfully saved 8 frames to character_frames/191
#
# Skipping 837 - 8 frames already exist
#
# Skipping 778 - 8 frames already exist
#
# Skipping 584 - 8 frames already exist
#
# Skipping 9288 - 8 frames already exist
#
# Skipping 829 - 8 frames already exist
#
# Skipping 846 - 8 frames already exist
#
# Skipping 17941 - 8 frames already exist
#
# Skipping 896 - 8 frames already exist
#
# Skipping 9715 - 8 frames already exist
#
# Skipping 19251 - 8 frames already exist
#
# Skipping 8958 - 8 frames already exist
#
# Skipping 338 - 8 frames already exist
#
# Skipping 764 - 8 frames already exist
#
# Skipping 8743 - 8 frames already exist
#
# Skipping 15574 - 8 frames already exist
#
# Skipping 10731 - 8 frames already exist
#
# Skipping 617 - 8 frames already exist
#
# Skipping 16054 - 8 frames already exist
#
# Skipping 5328 - 8 frames already exist
#
# Skipping 15207 - 8 frames already exist
#
# Skipping 11016 - 8 frames already exist
#
# Skipping 10563 - 8 frames already exist
#
# Skipping 446 - 8 frames already exist
#
# Skipping 101 - 8 frames already exist
#
# Skipping 772 - 8 frames already exist
#
# Skipping 19248 - 8 frames already exist
#
# Skipping 18920 - 8 frames already exist
#
# Skipping 5394 - 8 frames already exist
#
# Skipping 18941 - 8 frames already exist
#
# Skipping 16188 - 8 frames already exist
#
# Skipping 11563 - 8 frames already exist
#
# ...
# Frames saved to: character_frames
#   Extracted 8 frames
#   Saving 8 frames...
#   Successfully saved 8 frames to character_frames/1
#
# Skipping 11221 - 8 frames already exist
#
# Skipping 12747 - 8 frames already exist
#
# Skipping 17931 - 8 frames already exist
#
# Skipping 17573 - 8 frames already exist
#
# Skipping 5335 - 8 frames already exist
#
# Skipping 11813 - 8 frames already exist
#
# Skipping 741 - 8 frames already exist
#
# Skipping 742 - 8 frames already exist
#
# Skipping 230 - 8 frames already exist
#
# Skipping 873 - 8 frames already exist
#
# Skipping 534 - 8 frames already exist
#
# Skipping 4601 - 8 frames already exist
#
# Skipping 10414 - 8 frames already exist
#
# Skipping 160 - 8 frames already exist
#
# Skipping 532 - 8 frames already exist
#
# Skipping 3294 - 8 frames already exist
#
# Skipping 17786 - 8 frames already exist
#
# Skipping 801 - 8 frames already exist
#
# Skipping 569 - 8 frames already exist
#
# Skipping 453 - 8 frames already exist
#
# Skipping 377 - 8 frames already exist
#
# Skipping 10568 - 8 frames already exist
#
# Skipping 4770 - 8 frames already exist
#
# Skipping 6234 - 8 frames already exist
#
# Skipping 10426 - 8 frames already exist
#
# Skipping 5594 - 8 frames already exist
#
# Skipping 12224 - 8 frames already exist
#
# Skipping 608 - 8 frames already exist
#
# Skipping 12756 - 8 frames already exist
#
# Skipping 140 - 8 frames already exist
#
# Skipping 16908 - 8 frames already exist
#
# Skipping 18181 - 8 frames already exist
#
# Skipping 5091 - 8 frames already exist
#
# Skipping 4353 - 8 frames already exist
#
# Skipping 6409 - 8 frames already exist
#
# Skipping 14433 - 8 frames already exist
#
# Skipping 5249 - 8 frames already exist
#
# Skipping 3278 - 8 frames already exist
#
# Skipping 5337 - 8 frames already exist
#
# Skipping 209 - 8 frames already exist
#
# Skipping 14952 - 8 frames already exist
#
# Skipping 727 - 8 frames already exist
#
# Skipping 10397 - 8 frames already exist
#
# Skipping 548 - 8 frames already exist
#
# Skipping 471 - 8 frames already exist
#
# Skipping 7876 - 8 frames already exist
#
# Skipping 342 - 8 frames already exist
#
# Skipping 842 - 8 frames already exist
#
# Skipping 664 - 8 frames already exist
#
# Skipping 10966 - 8 frames already exist
#
# Skipping 407 - 8 frames already exist
#
# Skipping 12133 - 8 frames already exist
#
# Skipping 10640 - 8 frames already exist
#
# Skipping 756 - 8 frames already exist
#
# Skipping 98 - 8 frames already exist
#
# Skipping 908 - 8 frames already exist
#
# Skipping 17278 - 8 frames already exist
#
# Skipping 8746 - 8 frames already exist
#
# Skipping 5777 - 8 frames already exist
#
# Skipping 322 - 8 frames already exist
#
# Skipping 212 - 8 frames already exist
#
# Skipping 14796 - 8 frames already exist
#
# Skipping 14759 - 8 frames already exist
#
# Skipping 17933 - 8 frames already exist
#
# Skipping 681 - 8 frames already exist
#
# Skipping 872 - 8 frames already exist
#
# Skipping 5722 - 8 frames already exist
#
# Skipping 8119 - 8 frames already exist
#
# Skipping 9551 - 8 frames already exist
#
# Skipping 895 - 8 frames already exist
#
# Skipping 4323 - 8 frames already exist
#
# Skipping 485 - 8 frames already exist
#
# Skipping 10549 - 8 frames already exist
#
# Skipping 17136 - 8 frames already exist
#
# Skipping 12013 - 8 frames already exist
#
# Skipping 748 - 8 frames already exist
#
# Skipping 18284 - 8 frames already exist
#
# Skipping 17700 - 8 frames already exist
#
# Skipping 9453 - 8 frames already exist
#
# Skipping 5886 - 8 frames already exist
#
# Skipping 3281 - 8 frames already exist
#
# Skipping 5393 - 8 frames already exist
#
# Skipping 5770 - 8 frames already exist
#
# Skipping 900 - 8 frames already exist
#
# Skipping 729 - 8 frames already exist
#
# Skipping 4699 - 8 frames already exist
#
# Skipping 10086 - 8 frames already exist
#
# Skipping 4304 - 8 frames already exist
#
# Skipping 11330 - 8 frames already exist
#
# Skipping 331 - 8 frames already exist
#
# Skipping 12136 - 8 frames already exist
#
# Skipping 9297 - 8 frames already exist
#
# Skipping 16191 - 8 frames already exist
#
# Skipping 529 - 8 frames already exist
#
# Skipping 589 - 8 frames already exist
#
# Skipping 5164 - 8 frames already exist
#
# Skipping 828 - 8 frames already exist
#
# Skipping 9454 - 8 frames already exist
#
# Skipping 15078 - 8 frames already exist
#
# Skipping 400 - 8 frames already exist
#
# Skipping 4965 - 8 frames already exist
#
# Skipping 715 - 8 frames already exist
#
# Skipping 6760 - 8 frames already exist
#
# Skipping 860 - 8 frames already exist
#
# Skipping 70 - 8 frames already exist
#
# Skipping 450 - 8 frames already exist
#
# Skipping 800 - 8 frames already exist
#
# Skipping 5612 - 8 frames already exist
#
# Skipping 16896 - 8 frames already exist
#
# Skipping 486 - 8 frames already exist
#
# Skipping 12572 - 8 frames already exist
#
# Skipping 366 - 8 frames already exist
#
# Skipping 561 - 8 frames already exist
#
# Skipping 11020 - 8 frames already exist
#
# Skipping 16190 - 8 frames already exist
#
# Skipping 10011 - 8 frames already exist
#
# Skipping 514 - 8 frames already exist
#
# Skipping 644 - 8 frames already exist
#
# Skipping 16044 - 8 frames already exist
#
# Skipping 451 - 8 frames already exist
#
# Skipping 17569 - 8 frames already exist
#
# Skipping 4352 - 8 frames already exist
#
# Skipping 11225 - 8 frames already exist
#
# Skipping 133 - 8 frames already exist
#
# Skipping 79 - 8 frames already exist
#
# Skipping 10431 - 8 frames already exist
#
# Skipping 8904 - 8 frames already exist
#
# Skipping 461 - 8 frames already exist
#
# Skipping 17702 - 8 frames already exist
#
# Skipping 8626 - 8 frames already exist
#
# Skipping 236 - 8 frames already exist
#
# Skipping 250 - 8 frames already exist
#
# Skipping 8338 - 8 frames already exist
#
# Skipping 16814 - 8 frames already exist
#
# Skipping 612 - 8 frames already exist
#
# Skipping 10059 - 8 frames already exist
#
# Skipping 4493 - 8 frames already exist
#
# Skipping 11814 - 8 frames already exist
#
# Skipping 6464 - 8 frames already exist
#
# Skipping 611 - 8 frames already exist
#
# Skipping 6297 - 8 frames already exist
#
# Skipping 9409 - 8 frames already exist
#
# Skipping 224 - 8 frames already exist
#
# Skipping 557 - 8 frames already exist
#
# Skipping 594 - 8 frames already exist
#
# Skipping 5850 - 8 frames already exist
#
# Skipping 14345 - 8 frames already exist
#
# Skipping 15446 - 8 frames already exist
#
# Skipping 9408 - 8 frames already exist
#
# Skipping 14265 - 8 frames already exist
#
# Skipping 10823 - 8 frames already exist
#
# Skipping 4775 - 8 frames already exist
#
# Skipping 8707 - 8 frames already exist
#
# Skipping 12406 - 8 frames already exist
#
# Skipping 6191 - 8 frames already exist
#
# Skipping 239 - 8 frames already exist
#
# Skipping 5768 - 8 frames already exist
#
# Skipping 12611 - 8 frames already exist
#
# Skipping 476 - 8 frames already exist
#
# Skipping 698 - 8 frames already exist
#
# Skipping 352 - 8 frames already exist
#
# Skipping 735 - 8 frames already exist
#
# Skipping 431 - 8 frames already exist
#
# Skipping 8694 - 8 frames already exist
#
# Skipping 11010 - 8 frames already exist
#
# Skipping 6158 - 8 frames already exist
#
# Skipping 10487 - 8 frames already exist
#
# Skipping 9407 - 8 frames already exist
#
# Skipping 16684 - 8 frames already exist
#
# Skipping 771 - 8 frames already exist
#
# Skipping 672 - 8 frames already exist
#
# Skipping 6427 - 8 frames already exist
#
# Skipping 15245 - 8 frames already exist
#
# Skipping 15941 - 8 frames already exist
#
# Skipping 15987 - 8 frames already exist
#
# Skipping 223 - 8 frames already exist
#
# Skipping 14515 - 8 frames already exist
#
# Skipping 18184 - 8 frames already exist
#
# Skipping 4337 - 8 frames already exist
#
# Skipping 127 - 8 frames already exist
#
# Skipping 81 - 8 frames already exist
#
# Skipping 8079 - 8 frames already exist
#
# Skipping 8563 - 8 frames already exist
#
# Skipping 9656 - 8 frames already exist
#
# Skipping 18349 - 8 frames already exist
#
# Skipping 538 - 8 frames already exist
#
# Skipping 15795 - 8 frames already exist
#
# Skipping 9228 - 8 frames already exist
#
# Skipping 14437 - 8 frames already exist
#
# Skipping 9290 - 8 frames already exist
#
# Skipping 15925 - 8 frames already exist
#
# Skipping 18857 - 8 frames already exist
#
# Skipping 5398 - 8 frames already exist
#
# Skipping 4766 - 8 frames already exist
#
# Skipping 9226 - 8 frames already exist
#
# Skipping 267 - 8 frames already exist
#
# Skipping 12356 - 8 frames already exist
#
# Skipping 15988 - 8 frames already exist
#
# Skipping 123 - 8 frames already exist
#
# Skipping 680 - 8 frames already exist
#
# Skipping 3277 - 8 frames already exist
#
# Skipping 222 - 8 frames already exist
#
# Skipping 228 - 8 frames already exist
#
# Skipping 18862 - 8 frames already exist
#
# Skipping 11220 - 8 frames already exist
#
# Skipping 18344 - 8 frames already exist
#
# Skipping 11908 - 8 frames already exist
#
# Skipping 19105 - 8 frames already exist
#
# Skipping 430 - 8 frames already exist
#
# Skipping 14971 - 8 frames already exist
#
# Skipping 757 - 8 frames already exist
#
# Skipping 17147 - 8 frames already exist
#
# Skipping 12407 - 8 frames already exist
#
# Skipping 491 - 8 frames already exist
#
# Skipping 11025 - 8 frames already exist
#
# Skipping 12041 - 8 frames already exist
#
# Skipping 10567 - 8 frames already exist
#
# Skipping 192 - 8 frames already exist
#
# Skipping 8453 - 8 frames already exist
#
# Skipping 6157 - 8 frames already exist
#
# Skipping 261 - 8 frames already exist
#
# Skipping 530 - 8 frames already exist
#
# Skipping 17279 - 8 frames already exist
#
# Skipping 203 - 8 frames already exist
#
# Skipping 177 - 8 frames already exist
#
# Skipping 137 - 8 frames already exist
#
# Skipping 11030 - 8 frames already exist
#
# Skipping 489 - 8 frames already exist
#
# Skipping 11023 - 8 frames already exist
#
# Skipping 775 - 8 frames already exist
#
# Skipping 6242 - 8 frames already exist
#
# Skipping 813 - 8 frames already exist
#
# Skipping 14962 - 8 frames already exist
#
# Skipping 9452 - 8 frames already exist
#
# Skipping 8628 - 8 frames already exist
#
# Skipping 18351 - 8 frames already exist
#
# Skipping 17785 - 8 frames already exist
#
# Skipping 7774 - 8 frames already exist
#
# Skipping 841 - 8 frames already exist
#
# Skipping 8170 - 8 frames already exist
#
# Skipping 8245 - 8 frames already exist
#
# Skipping 19256 - 8 frames already exist
#
# Skipping 5086 - 8 frames already exist
#
# Skipping 10831 - 8 frames already exist
#
# Skipping 717 - 8 frames already exist
#
# Skipping 5176 - 8 frames already exist
#
# Skipping 6268 - 8 frames already exist
#
# Skipping 8304 - 8 frames already exist
#
# Skipping 12175 - 8 frames already exist
#
# Skipping 18337 - 8 frames already exist
#
# Skipping 314 - 8 frames already exist
#
# Skipping 345 - 8 frames already exist
#
# Skipping 12341 - 8 frames already exist
#
# Skipping 8123 - 8 frames already exist
#
# Skipping 6522 - 8 frames already exist
#
# Skipping 207 - 8 frames already exist
#
# Skipping 159 - 8 frames already exist
#
# Skipping 14975 - 8 frames already exist
#
# Skipping 17578 - 8 frames already exist
#
# === PROCESSING COMPLETE ===
# Successfully processed: 5 characters
# Skipped (already exist): 2333 characters
# Failed: 0 characters
# Total frames saved: 40
# Skipped characters: ['8097', '9549', '18605', '730', '4307', '6245', '432', '905', '16696', '11447', '76', '10094', '201', '16189', '4616', '743', '11326', '10645', '8024', '3269', '19172', '9556', '8098', '5312', '6156', '10643', '5245', '469', '6700', '686', '9664', '674', '10552', '391', '9710', '5883', '17789', '809', '595', '9662', '539', '18939', '4293', '218', '17408', '442', '4378', '4488', '652', '245', '11565', '17792', '677', '348', '478', '518', '12411', '188', '568', '15083', '408', '18863', '32', '5451', '149', '4399', '78', '9949', '8960', '306', '380', '6159', '11446', '12162', '11318', '8878', '10092', '14451', '12040', '266', '8705', '465', '628', '17848', '268', '16193', '11564', '220', '398', '6761', '803', '4938', '6615', '836', '193', '369', '12749', '9071', '34', '9560', '10008', '574', '740', '6764', '17143', '14512', '399', '641', '11013', '467', '17149', '5175', '3292', '5774', '675', '124', '5928', '4303', '10454', '8021', '139', '5081', '16912', '427', '8780', '5169', '9832', '7781', '11223', '7785', '104', '15565', '12141', '9711', '15983', '12750', '643', '5528', '9552', '414', '10491', '11320', '11', '15086', '822', '17150', '487', '11915', '17567', '17582', '4897', '11569', '8339', '10534', '18073', '15088', '173', '7777', '780', '14702', '365', '488', '17132', '2', '460', '540', '4389', '9708', '15571', '17944', '308', '4729', '704', '16679', '16686', '745', '5244', '17083', '762', '17571', '10521', '5442', '546', '6291', '11443', '495', '19101', '176', '17787', '234', '16198', '9448', '334', '6516', '3319', '248', '214', '5726', '166', '8235', '722', '5247', '14447', '6026', '739', '6009', '19109', '5858', '15982', '216', '898', '14154', '8337', '558', '18340', '195', '508', '11322', '11222', '459', '12835', '8668', '41', '15794', '14152', '11217', '871', '6131', '19246', '8191', '17701', '879', '45', '361', '336', '4606', '6587', '18343', '4494', '553', '519', '282', '17137', '603', '240', '19243', '798', '11024', '9716', '12138', '8959', '280', '669', '11014', '8331', '5153', '5064', '14511', '106', '35', '6465', '523', '4301', '9449', '8341', '659', '393', '10486', '573', '869', '291', '10821', '17134', '6521', '15034', '229', '876', '12019', '4462', '125', '9669', '6244', '16899', '5080', '815', '5659', '107', '12219', '9614', '19098', '11449', '294', '17491', '645', '728', '531', '333', '213', '153', '845', '5525', '6215', '18074', '812', '11819', '14510', '196', '15578', '437', '8515', '5251', '6720', '18352', '17122', '167', '647', '12755', '4490', '575', '821', '494', '18179', '16029', '199', '18938', '8125', '254', '18604', '208', '567', '9545', '515', '18858', '5330', '9291', '4640', '5859', '19108', '8632', '372', '11319', '353', '707', '148', '5180', '19255', '9667', '755', '17148', '894', '695', '648', '5444', '48', '15977', '14504', '8744', '4486', '5927', '5243', '524', '260', '6241', '9198', '11567', '12405', '6706', '18855', '856', '17152', '17126', '883', '18945', '9455', '16186', '10429', '17145', '10826', '9070', '4602', '367', '285', '272', '12218', '11910', '5443', '10009', '746', '11916', '790', '16621', '18075', '16816', '605', '5526', '9068', '10085', '551', '59', '10089', '7606', '779', '43', '6401', '9630', '12401', '350', '4768', '11909', '525', '5297', '19068', '4283', '5366', '4683', '4369', '526', '112', '517', '263', '8023', '9406', '10819', '17780', '621', '19046', '439', '912', '8765', '163', '355', '119', '18334', '499', '5769', '777', '720', '11815', '10062', '9497', '15445', '9040', '751', '4391', '23', '6236', '6338', '11818', '9958', '346', '17579', '692', '5085', '15569', '17783', '12577', '9035', '8192', '8554', '4753', '9267', '412', '62', '283', '347', '12402', '9550', '4903', '15579', '200', '17575', '7784', '8900', '15000', '9657', '785', '15577', '9069', '4607', '17493', '4651', '6403', '9498', '666', '16090', '16690', '9132', '492', '4926', '17130', '4491', '462', '12165', '631', '572', '737', '17492', '506', '19020', '696', '799', '324', '204', ' ...
# Frames saved to: character_frames

# %%
# Example: Visualize frames for a specific character
# Replace 'CHARACTER_ID' with an actual character ID from your videos
# visualize_character_frames('CHARACTER_ID')

# Or visualize the first character found
if all_results:
    first_character = list(all_results.keys())[0]
    print(f"Visualizing frames for character: {first_character}")
    visualize_character_frames(first_character)
# Out:
# Visualizing frames for character: 8097
# Showing 8 frames out of 8 total frames
